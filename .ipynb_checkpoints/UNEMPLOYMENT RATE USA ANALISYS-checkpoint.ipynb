# %% [markdown]
# # Análisis univariante de una serie temporal : Paro en Estados Unidos

# %% [markdown]
# En este notebook procederemos a realizar el análisis univariante de una serie estocástica, en concreto de la tasa de paro de Estados Unidos en el sector primario. Los datos han sido sacados del FED disponibles en esta página: https://fred.stlouisfed.org/
#
# Por supuesto el paro es una magnitud macroeconómica muy compleja y valor actual depende de muchas cosas más aparte de sus valores pasados, el objetivo de este notebook no es otro que el de mostrar las herramientas del análisis univariante de series temporales que Python ofrece.
#
#
# ***

# %% [markdown]
# #### Creamos el entorno de trabajo.

# %%
# Librerias de trabajo 

#Manejo de datos
import pandas as pd
from pandas import DatetimeIndex

#Cientifico
from scipy import stats
import numpy as np
import math

#Estadisticas 
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.stats.diagnostic as tsa

#Grafico
import matplotlib.pyplot as plt
from statsmodels.graphics.api import qqplot
# %matplotlib inline

# %%
#Cargamos los daros y cambiamos el nombre de las columnas
df = pd.read_excel("fredgraph.xls",skiprows=(14))
columnas = ["fecha","Primario","Transportes","Servicios","Oficina","alto_cargo"]
df.columns = columnas
df.index = DatetimeIndex(df["fecha"])
df.shape
# Out:
# (225, 6)

# %%
#comprobamos si hay valores nulos
pd.isnull(df).any()
# Out:
# fecha          False
# Primario       False
# Transportes    False
# Servicios      False
# Oficina        False
# alto_cargo     False
# dtype: bool

# %%
df["mean_paro"] = df.mean(axis=1)
df.tail()
# Out:
#                 fecha  Primario  Transportes  Servicios  Oficina  alto_cargo  \
# fecha
# 2018-05-01 2018-05-01       4.6          4.6        4.3      3.8         1.7
# 2018-06-01 2018-06-01       4.8          4.4        5.0      3.8         2.5
# 2018-07-01 2018-07-01       3.8          4.4        5.1      4.0         2.4
# 2018-08-01 2018-08-01       3.8          4.5        4.6      3.8         2.5
# 2018-09-01 2018-09-01       3.8          4.3        4.3      3.6         2.0
#
#             mean_paro
# fecha
# 2018-05-01       3.80
# 2018-06-01       4.10
# 2018-07-01       3.94
# 2018-08-01       3.84
# 2018-09-01       3.60

# %%
df1 = df[df.columns[1:7]]
df1.plot(legend= True,figsize=(15,10))

# %% [markdown]
# Pasemos a analizar solo el paro del sector primario

# %% [markdown]
# ### Aplicamos transformacion de Box- Cox

# %% [markdown]
# ***
# Ya a simple vista podemos observar que la tasa de paro en el sector ``Primario`` es mucho más acusada que en el resto de los sectores, soportando subidas y bajadas mucho más acusadas que en el resto de los sectores.

# %%
# Aplicamos logaritmos
df["ln_Primario"] = df.Primario.apply(math.log)
df["ln_Transportes"]= df.Transportes.apply(math.log)
df["ln_Servicios"] = df.Servicios.apply(math.log)
df["ln_Oficina"]= df.Oficina.apply(math.log)
df["ln_alto_cargo"]= df.alto_cargo.apply(math.log)
df["ln_mean_paro"]= df.mean_paro.apply(math.log)

# %%
dfest = df[df.columns[7:]]
dfest.plot(legend= True,figsize=(15,10),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001DE9F052D30>,
# ...
#       dtype=object)

# %% [markdown]
# Esto lo podríamos interpretar como la tasa de crecimiento de la tasa de paro según los distintos sectores. Podemos apreciar que se mueven de forma bastante parecidas

# %% [markdown]
# ## Filtro Hodrick y Prescott

# %% [markdown]
# El filtro HP es uno delos más usados en economia para el analisis del PIB, separando la tendencia del ciclo de forma que:$$y_t\ = \tau_t\ + c_t\ + \epsilon_t\,$$
# El filtro HP funciona segun la minimizacion de la siguente función cuadratica:
# <math>$$\min_{\tau}\left(\sum_{t = 1}^T {(y_t - \tau _t )^2 }  + \lambda \sum_{t = 2}^{T - 1} {[(\tau _{t+1}  - \tau _t) - (\tau _t  - \tau _{t - 1} )]^2 }\right).\,$$</math>
#
# Para ajustar la sensibilidad del filtro se hace mrdiante el ajuste del parameto $\lambda$ que para nuestro caso, el de una serie mensual se ajustaria a 1400.

# %%
#Ejecutamos el filtro y nos separa la tendencia del ciclo
cycle, trend = sm.tsa.filters.hpfilter(df.ln_Primario, 14400)

# %%
df["ciclo"]= cycle
df["tendencia"]=trend

# %%
df[["ln_Primario","tendencia"]].plot(figsize=(12,8))

# %%
df[["ciclo"]].plot(figsize=(12,8))

# %% [markdown]
# Con esto podremos pasar a analizar el ciclo.

# %%
#corelogramas de el ln de Primario, diferenciado 1 periodo
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.ciclo, lags=60, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.ciclo, lags=60, ax=ax2)

# %%
modelo= sm.tsa.ARMA(df.ciclo, order=(2,1) )
arma_res = modelo.fit(disp=True)
print(arma_res.summary())
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                  ciclo   No. Observations:                  225
# Model:                     ARMA(2, 1)   Log Likelihood                 224.747
# Method:                       css-mle   S.D. of innovations              0.089
# Date:                Fri, 26 Oct 2018   AIC                           -439.494
# Time:                        19:06:08   BIC                           -422.413
# Sample:                    01-01-2000   HQIC                          -432.600
#                          - 09-01-2018
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0004      0.013      0.028      0.978      -0.024       0.025
# ar.L1.ciclo     1.5864      0.049     32.084      0.000       1.490       1.683
# ar.L2.ciclo    -0.8155      0.043    -18.834      0.000      -0.900      -0.731
# ...

# %% [markdown]
# **Este modelo es estacionario**
#
# Como podemos observar sus raíces están fuera del circulo unidad y todos los coeficientes son significativos, menos la constante, pero al ser tan pequeño su valor no nos afecta.
# Pero veamos  cómo se comporta.

# %%
df["arma_res"]= arma_res.fittedvalues 
dffit = df[["ciclo","arma_res"]]

# %%
dffit.plot(figsize=(18,10))

# %% [markdown]
# Parece que se ajusta más o menos bien, veamos cómo se comportan los residuos.

# %%
resid = arma_res.resid

# %%
stats.normaltest(resid)
# Out:
# NormaltestResult(statistic=0.28609686758448305, pvalue=0.866712089725605)

# %% [markdown]
# * La hipótesis nula es que los residuos siguen una distribución normal, la cual no rechazamos ya que el p-valor es mayor que 0,05.

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
fig = qqplot(resid, line='q', ax=ax, fit=True)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax = arma_res.resid.plot(ax=ax)

# %%
sm.stats.durbin_watson(arma_res.resid.values)
# Out:
# 2.0377343942179227

# %% [markdown]
# El test D-W es próximo a 2 y no es un valor extremo ( 0 o 4 ) por lo que determinamos que está bien especificado.

# %% [markdown]
# Representamos el correlograma de los errores.

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(arma_res.resid.values, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(arma_res.resid.values, lags=40, ax=ax2)

# %% [markdown]
# Por el correlograma podemos comprobar que no sigue un proceso de ruido blanco ya que hay bastantes valores  que sobresalen de las bandas de confianza.

# %% [markdown]
# Veamos ahora con el test de Jung - Box si se comportan como un ruido blanco.

# %%
tsa.acorr_ljungbox(arma_res.resid.values, lags=None, boxpierce=True)
# Out:
# (array([  0.52332196,   1.81506023,   2.15110085,   2.43635067,
#           8.89313032,  13.35891685,  21.60127209,  27.24117397,
#          28.97642437,  28.99385838,  34.53013561,  62.31517108,
#          62.9678118 ,  62.97644951,  71.21339651,  77.97292875,
#          78.127372  ,  78.59215285,  78.79370646,  88.09835856,
#         103.70165238, 103.97378292, 104.04518192, 123.56593124,
#         123.59737517, 125.11523348, 135.49270827, 149.91909861,
#         150.16722958, 150.59303461, 150.6899739 , 160.04598385,
#         174.64752177, 174.91741383, 175.90663079, 188.41391723,
#         188.63930542, 189.44027804, 195.49020318, 201.57613454]),
#  array([4.69428059e-01, 4.03519642e-01, 5.41644085e-01, 6.56068287e-01,
#         1.13403509e-01, 3.76774650e-02, 2.97505658e-03, 6.42279489e-04,
#         6.54001231e-04, 1.24890054e-03, 2.96105999e-04, 8.51383488e-09,
#         1.53860468e-08, 3.50383716e-08, 2.71328318e-09, 3.85076394e-10,
# ...

# %% [markdown]
# El segundo array es el que contiene los p-valores con la significación de los residuos. Podemos ver que los p-valores sí que son más pequeños a 0,05 por lo tanto rechazamos la hipótesis nula, los residuos no siguen un ruido blanco.

# %% [markdown]
# Segun el test los residuos no se acaban de comportar como un riudo blanco. Por los tanto tendriamos que reestimar el modelo

# %% [markdown]
# #### Pasemos a la predicción

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = df.ciclo.plot(ax=ax)
fig = arma_res.plot_predict('2018-09-01', '2025', dynamic=True, ax=ax, plot_insample=False)

# %% [markdown]
# Es normal que tengamos esta predicción teniendo en cuenta que los errores no siguen un ruido blanco y eso quiere decir que el modelo no capta del todo el efecto.
# Podemos concluir que esta predicción no es nada fiable.

# %% [markdown]
# ***

# %% [markdown]
# ### Pasemos ahora a un modelo ARIMA
#
# Esto sería un procero ARMA aplicado a la diferencia ΔlogXtΔlogXt esto lo podríamos interpretar a la práctica como un modelo que defina la tasa de variación de la tasa de paro del sector primario en USA. En este caso estamos analizando la serie original no el ciclo.

# %%
# Aplicamos proceso diferencia
df["ln_Primario_dif"] = df.ln_Primario.diff()
df = df.dropna()

# %%
df.head()
# Out:
#                 fecha  Primario  Transportes  Servicios  Oficina  alto_cargo  \
# fecha
# 2000-02-01 2000-02-01       7.8          5.7        5.8      4.2         1.7
# 2000-03-01 2000-03-01       6.6          5.7        5.8      3.9         1.8
# 2000-04-01 2000-04-01       4.8          5.3        4.4      3.7         1.5
# 2000-05-01 2000-05-01       4.4          4.8        5.1      4.0         1.6
# 2000-06-01 2000-06-01       4.5          4.6        5.7      4.0         1.9
#
#             mean_paro  ln_Primario  ln_Transportes  ln_Servicios  ln_Oficina  \
# fecha
# 2000-02-01       5.04     2.054124        1.740466      1.757858    1.435085
# 2000-03-01       4.76     1.887070        1.740466      1.757858    1.360977
# 2000-04-01       3.94     1.568616        1.667707      1.481605    1.308333
# 2000-05-01       3.98     1.481605        1.568616      1.629241    1.386294
# 2000-06-01       4.14     1.504077        1.526056      1.740466    1.386294
#
# ...

# %%
#corelogramas de el ln de Primario, diferenciado 1 periodo
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.ln_Primario_dif, lags=50, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.ln_Primario_dif, lags=50, ax=ax2)

# %%
modelo2= sm.tsa.ARMA(df.ln_Primario_dif, order=(2,2))
arma_res2 = modelo2.fit(disp=True)
print(arma_res2.summary())
# Out:
# C:\Users\tito-\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:171: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
#                               ARMA Model Results
# ...
# Dep. Variable:        ln_Primario_dif   No. Observations:                  224
# Model:                     ARMA(2, 2)   Log Likelihood                 230.901
# Method:                       css-mle   S.D. of innovations              0.085
# Date:                Fri, 26 Oct 2018   AIC                           -449.802
# Time:                        19:06:47   BIC                           -429.332
# Sample:                    02-01-2000   HQIC                          -441.539
#                          - 09-01-2018
# ...
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# En este caso podemos observar que es estacionario ya que el módulo de las raíces es mayor que uno. Los coeficientes son significativos menos, como en el caso anterior, la constante.

# %%
df["arma_res2"]= arma_res2.fittedvalues 
dffit = df[["ln_Primario_dif","arma_res2"]]
dffit.plot(figsize=(18,10))

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
ax = arma_res2.resid.plot(ax=ax)

# %%
resid2 = arma_res2.resid

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid2.values, lags=40, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid2, lags=40, ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
fig = qqplot(resid2, line='q', ax=ax, fit=True)

# %%
sm.stats.durbin_watson(arma_res2.resid.values)
# Out:
# 1.967760914902907

# %%
stats.normaltest(resid2)
# Out:
# NormaltestResult(statistic=1.0231699767775493, pvalue=0.5995445541729394)

# %%
tsa.acorr_ljungbox(arma_res2.resid.values, lags=None, boxpierce=True)
# Out:
# (array([4.36908201e-02, 1.53351901e-01, 1.43257237e+00, 2.26628090e+00,
#         1.22706608e+01, 2.96534000e+01, 4.19288423e+01, 4.84514629e+01,
#         5.47420371e+01, 5.73368333e+01, 6.22155982e+01, 9.02861282e+01,
#         9.24032822e+01, 9.24082549e+01, 9.95045329e+01, 1.03011739e+02,
#         1.09511550e+02, 1.22566408e+02, 1.27678739e+02, 1.30866600e+02,
#         1.51329014e+02, 1.53236838e+02, 1.53255288e+02, 1.71885092e+02,
#         1.72667050e+02, 1.74899812e+02, 1.85656611e+02, 1.94069530e+02,
#         1.98614562e+02, 2.09780161e+02, 2.12928709e+02, 2.17423810e+02,
#         2.36118801e+02, 2.38209209e+02, 2.38679460e+02, 2.49751470e+02,
#         2.50250931e+02, 2.52331823e+02, 2.63322026e+02, 2.70405251e+02]),
#  array([8.34429900e-01, 9.26189936e-01, 6.97917662e-01, 6.86914693e-01,
#         3.12615367e-02, 4.57432609e-05, 5.36661332e-07, 8.09794978e-08,
#         1.36387382e-08, 1.15217527e-08, 3.58451214e-09, 4.34604862e-14,
# ...

# %% [markdown]
# Según el test Jung-Box y las demás comprobaciones realizadas podemos concluir que los errores de este modelo tampoco se comportan como un ruido blanco.

# %% [markdown]
# ### Pasemos ahora a la predicción

# %%
fig, ax = plt.subplots(figsize=(12, 8))
ax = df.ln_Primario_dif.plot(ax=ax)
fig = arma_res2.plot_predict('2016-09-01', '2019', dynamic=True, ax=ax, plot_insample=False)

# %% [markdown]
# Como en el caso anterior, no podemos fiarno de la predicción.
